# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py

# %%
def center_crop(data,shape): 
    """
    Apply a center crop to the input real image or batch of real images.
    Args:
        data: The input tensor to be center cropped. It should
            have at least 2 dimensions and the cropping is applied along the
            last two dimensions.
        shape: The output shape. The shape should be smaller
            than the corresponding dimensions of data.
    Returns:
        The center cropped image.
    """
    if not (0 < shape[0] <= data.shape[-2] and 0 < shape[1] <= data.shape[-1]):
        raise ValueError("Invalid shapes.")

    w_from = (data.shape[-2] - shape[0]) // 2
    h_from = (data.shape[-1] - shape[1]) // 2
    w_to = w_from + shape[0]
    h_to = h_from + shape[1]

    return data[..., w_from:w_to, h_from:h_to]

# %%
# # here I load the recon_test file
# recon_test = h5py.File('/home/svangurp/scratch/reconstructions/fastmri_brain_test/zero_filled/from_test_set/file_brain_AXFLAIR_200_6002441.h5', 'r')
# recon_test.keys()

# %%
# recon_test_kspace = recon_test['kspace']
# recon_test_kspace.shape

# %%
data = h5py.File('/scratch/svangurp/fastMRI/brain/train/file_brain_AXFLAIR_200_6002425.h5', 'r')
data.keys()
# Out:
# <KeysViewHDF5 ['ismrmrd_header', 'kspace', 'reconstruction_rss']>

# %%
kspace = data['kspace']
recon_rss= data['reconstruction_rss']
print(kspace.shape)
print(recon_rss.shape)
# recon_train_ifft =  recon_train_ifft/np.max(np.abs(recon_train_ifft))
# Out:
# (16, 20, 640, 320)
# (16, 320, 320)

# %%
# print('number of non zero elements in k-space',np.count_nonzero(np.abs(recon_train[5])))

plt.imshow(np.abs(recon_rss[5]), cmap='gray')
plt.title('rss recon of fully sampled data')
plt.show()




# print('min:',np.min(np.abs(recon_train_ifft)))
# print('max',np.max(np.abs(recon_train_ifft)))
# plt.imshow(np.abs(recon_train_ifft), cmap='gray')
# plt.title('k-space fully sampled data')
# plt.show()

# plt.imshow(np.imag(recon_train_ifft), cmap='gray')
# plt.title('k-space phase fully sampled data')
# plt.show()

# %%
im_space = np.fft.fftshift(np.fft.ifftn(np.fft.ifftshift(kspace,axes = (-2,-1)),axes = (-2,-1)),axes = (-2,-1))
# im_space = im_space/np.max(np.abs(im_space))

croped_imspace = center_crop(im_space,(320,320))

rss_imspace = np.sqrt(np.sum(croped_imspace**2,1))
rss_imspace = np.sqrt(np.sum(croped_imspace**2,1))
plt.imshow(np.abs(rss_imspace[5]),cmap='gray')
plt.show()


diff = np.abs(rss_imspace) - np.abs(recon_rss) 

plt.imshow(diff[5],cmap='gray')
plt.show()

# %%
print('number of non zero elements in k-space',np.count_nonzero(np.abs(recon_test_kspace[0][5])))
plt.imshow(np.abs(recon_test_kspace[0][5]), cmap='gray')
plt.title('k-space  subsampled data')
plt.show()

recon_test_FT = np.fft.fftshift(np.fft.fftn(recon_test_kspace[0][5]))
plt.imshow(np.abs(recon_test_FT), cmap='gray')
plt.title('image space subsampled data')
plt.show()

# %%
# creation of disk mask
height = 320
width = 320
radius = 20
mask = np.multiply(np.abs(np.random.randint(0,2,(height,width))),np.abs(np.random.randint(0,2,(height,width))))
for i in range(height):
    for j in range(width):
        if np.sqrt(((i-(height/2))**2)+(j-(width/2))**2) <= radius:
            mask[i][j] = 1
print(np.count_nonzero(mask))

plt.imshow(mask)
plt.show()

# %%
masked_kspace = np.multiply(mask,recon_train_ifft)
accsleration = mask.size/mask.sum()
print(accsleration)
print('number of non zero elements in k-space',np.count_nonzero(np.abs(masked_kspace)))

plt.imshow(np.abs(np.log(masked_kspace)), cmap='gray')
plt.title('k-space masked data')
plt.show()

masked_train_image = np.fft.ifftn(masked_kspace)
plt.imshow(np.abs(masked_train_image), cmap='gray')
plt.title('image space fully masked data')
plt.show()

# %%
#parallel mask 

height = 320
width = 320
number_of_lines = 100
step = int(height/number_of_lines)
parallel_mask = np.zeros((height,width))

for i in range(0,height,step):
    parallel_mask[i][:] = 1

#plot loos wierd because lines are missing but they are there in the matrix
plt.imshow(parallel_mask, cmap='gray')
plt.show()    

parallel_masked_kspace = np.multiply(parallel_mask,recon_train_ifft)
print('number of non zero elements in k-space',np.count_nonzero(np.abs(masked_kspace)))

plt.imshow(np.abs(parallel_masked_kspace), cmap='gray')
plt.title('k-space masked data')
plt.show()




masked_train_image = np.fft.ifftn(parallel_masked_kspace)
plt.imshow(np.abs(masked_train_image), cmap='gray')
plt.title('image space fully parallel masked data')
plt.show()

# %%
print('number of non zero elements in k-space',np.count_nonzero(np.abs(recon_test_kspace[0][5])))
plt.imshow(np.abs(recon_test_kspace[0][5]), cmap='gray')
plt.title('k-space  subsampled data')
plt.show()

recon_test_FT = np.fft.fftshift(np.fft.fftn(recon_test_kspace[0][5]))
plt.imshow(np.abs(recon_test_FT), cmap='gray')
plt.title('image space subsampled data')
plt.show()

# %%
height = 320
width = 320
radius = 20
mask = np.multiply(np.abs(np.random.randint(0,2,(height,width))),np.abs(np.random.randint(0,2,(height,width))))

for i in range(height):
    for j in range(width):
        if np.sqrt(((i-(height/2))**2)+(j-(width/2))**2) <= radius:
            mask[i][j] = 1
print(np.count_nonzero(mask))
plt.imshow(mask)
plt.show()

# %%
masked_kspace = np.multiply(mask,recon_train_ifft)
print('number of non zero elements in k-space',np.count_nonzero(np.abs(masked_kspace)))

plt.imshow(np.abs(masked_kspace), cmap='gray')
plt.title('k-space masked data')
plt.show()

masked_train_image = np.fft.ifftn(masked_kspace)
plt.imshow(np.abs(masked_train_image), cmap='gray')
plt.title('image space fully masked data')
plt.show()

# %%
#parallel mask 

height = 320
width = 320
number_of_lines = 100r = int(height/number_of_lines)
parallel_mask = np.zeros((height,width))

for i in range(0,height,step):
    parallel_mask[i][:] = 1

#plot loos wierd because lines are missing but they are there in the matrix
plt.imshow(parallel_mask, cmap='gray')
plt.show()    

parallel_masked_kspace = np.multiply(parallel_mask,recon_train_ifft)
print('number of non zero elements in k-space',np.count_nonzero(np.abs(masked_kspace)))

plt.imshow(np.abs(parallel_masked_kspace), cmap='gray')
plt.title('k-space masked data')
plt.show()

parallel_masked_kspace = np.fft.ifftn(masked_kspace)
plt.imshow(np.abs(masked_train_image), cmap='gray')
plt.title('image space fully masked data')
plt.show()

# %%
print(parallel_mask[48][1])
